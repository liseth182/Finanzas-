# %% [markdown]
# <a href="https://colab.research.google.com/github/Eafit-Ingenieria-Agronomica/Agricultura-Predictiva-2025_II/blob/main/Talleres/Taller_2/Imputación.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>

# %% [markdown]
# ## Agricultura Predictiva
# ### Taller _2: Exploración y limpieza de datos

# %% [markdown]
# <img src='https://upload.wikimedia.org/wikipedia/commons/a/ad/Plodozmian.jpg' width="1200" height="1000">

# %% [markdown]
# Fuente imagen: wikipedia

# %% [markdown]
# ---
#
# #**Análisis del Rendimiento de Cultivos**
#
# La predicción del rendimiento de los cultivos es un problema agrícola importante. El rendimiento agrícola depende principalmente de las condiciones climáticas (lluvia, temperatura, etc.), de los pesticidas, y de contar con información precisa sobre el historial de rendimiento de los cultivos, lo cual es clave para tomar decisiones relacionadas con la gestión de riesgos agrícolas y las predicciones futuras. En este taller, se usarán datos de rendimiento de los diez cultivos más consumidos en el mundo según el sitio web de la FAO y modificados con fines didácticos. Los datos recopilados incluyen país, ítem (tipo de cultivo), año (desde 1961 hasta 2016) y el valor del rendimiento.
#
# Estos cultivos incluyen:
#
# * Yuca
# * Maíz
# * Plátanos y otros
# * Papas
# * Arroz (arroz con cáscara)
# * Sorgo
# * Soya
# * Camote
# * Trigo
# * Ñame
#
# cultivos (en ingles nombre original):
#
# - Cassava
# - Maize
# - Plantains and others
# - Potatoes
# - Rice, paddy
# - Sorghum
# - Soybeans
# - Sweet potatoes
# - Wheat
# - Yams
# ---

# %% [markdown]
# #1.Importar las librerias

# %%
# importar librerías
import numpy as np
import pandas as pd

# %%
#montar google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**2.Datos de rendimiento de cultivos** 📈

# %% [markdown]
# ##Leer datos de Rendimiento de Cultivos

# %%
df_yield=pd.read_csv('/content/drive/MyDrive/Predictiva /taller_predictiva/produccion.csv')
df_yield #Leer datos tabulares usando pandas
# Out:
#       Domain Code Domain  Area Code         Area  Element Code Element  \
# 0              QC  Crops          2  Afghanistan          5419   Yield
# 1              QC  Crops          2  Afghanistan          5419   Yield
# 2              QC  Crops          2  Afghanistan          5419   Yield
# 3              QC  Crops          2  Afghanistan          5419   Yield
# 4              QC  Crops          2  Afghanistan          5419   Yield
# ...           ...    ...        ...          ...           ...     ...
# 56715          QC  Crops        181     Zimbabwe          5419   Yield
# 56716          QC  Crops        181     Zimbabwe          5419   Yield
# 56717          QC  Crops          2  Afghanistan          5419   Yield
# 56718          QC  Crops          2  Afghanistan          5419   Yield
# 56719          QC  Crops          2  Afghanistan          5419   Yield
#
#        Item Code  Year Code  Year   Unit       Value
# 0             56       1961  1961  hg/ha  14000hg/ha
# ...

# %% [markdown]
# ##Explorar datos

# %%
#Obtener shape de los datos (filas,columnas)
display(df_yield.shape)
# Out:
# (56720, 11)

# %%
#Lista de los nombres de los campos de una tabla

# %%
#Mostrar los primeras n filas(registros) del dataframe(tabla)

# %%
#Mostrar las ultimas n filas(registros) del dataframe(tabla)

# %%
#Descripción de la Información de la tabla y tipo de datos

# %% [markdown]
# ##Selección preliminar de características

# %% [markdown]
# ###Identificar campos con valores constantes, campos repetidos o redundantes

# %% [markdown]
# Los campos constantes son aquellos que tienen un mismo valor en todas sus celdas, por lo tanto el campo posee un solo valor único, una revisión visual de los primeros y últimos registros de la tabla puede sugerir posibles candidatos, pero no es confiable cuando el número de filas es grande, así que confirmamos los posibles campos constantes usando el método [.nunique()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.nunique.html) de pandas.

# %%
#Conteo de valores únicos por columna usando pandas

# %%
#Revisar si un campo tiene todos sus valores igual a otro campo por ejemplo "Year" y "Year Code"
campo1="Year"
campo2="Year Code"

if np.array_equal(df_yield[campo1],df_yield[campo2]) == True:
    print("campo1 y campo2 son iguales") #imprime si ambos campos son iguales

# %%
# Descartar columnas no deseadas (conservando el orden de las columnas restantes).

# %% [markdown]
# ##Relacionar tablas por un campo en común

# %% [markdown]
# El campo “Item Code” guarda el código de cultivo para cada registro, así que éste puede ser usado como campo clave para relacionar las tablas de producción y de códigos de cultivos. De esta manera se logra tener en una sola tabla la información de producción y los nombres de los cultivos

# %%
codigo_cultivos_df= #Leer tabla con los códigos de cultivos

# %%
#relacionar las tablas de producción y de códigos de cultivos por el campo "Item_Code". Use el método merge de pandas.

# %%
# Descripción de la información de la tabla anterior y tipo de datos

# %%
#Con base en la tabla anterior seleccionar los campos deseados y con un orden específico 'Area','Item','Year','Value'

# %% [markdown]
# ##Limpieza de datos

# %% [markdown]
# #### Cambiar nombres de campos (Renombrar columnas): Al observar los nombres de las columnas, podemos renombrar 'Value' a 'hg/ha_yield' para que sea más fácil reconocer que éste es el valor de producción/rendimiento de los cultivos.

# %%
# Renombrar columnas. Use el metodo rename de pandas

# %% [markdown]
# ###Identificar nulos (NaN)

# %%
#Contar cantidad de valores nulos por campo(columna)

# %%
# porcentaje de nulos por columna

# %% [markdown]
# **Muchos algoritmos no admiten valores nulos** o generan resultados erróneos o sin sentido al operar sobre este tipo de datos, por lo tanto antes de efectuar operaciones con los valores de la tabla **las filas que poseen estos valores nulos deben ser identificadas**

# %%
# Calcular porcentaje de filas con al menos un NaN

# %%
#Mostrar las filas con valores nulos

# %% [markdown]
# ###Eliminar filas con valores nulos

# %% [markdown]
# Antes de eliminar filas con valores nulos, evalúa:
#
# ¿Qué columnas están afectadas?: si las columnas afectadas no son importantes, elimina las columnas.
#
# ¿Qué porcentaje del total de las filas representan?: Para este ejercicio si el porcentaje es bajo, menor de un 20%, asumimos que eliminar los registros no causará problemas para aplicar métodos de regresión.
#
# ¿Puedes o debes imputar en lugar de eliminarlos?: El valor faltante se puede estimar o imputar, por ejemplo puedes imputar con la media, mediana o usar técnicas de imputación más avanzadas. Pero es importante tener en cuenta que entre más complejos los datos, más difícil es encontrar un valor que se ajuste correctamente a las dinámicas presentes en los datos.
#
# **Para estos datos en particular, dada la baja cantidad de filas con valores nulos se decide eliminarlas**

# %%
#imprimir shape de la tabla (filas, columnas) antes de eliminar registros con valores nulos para comparar.

# %%
#Eliminar filas con valores nulos (usar cuando la cantidad relativa de filas con nulos es baja, menor del 20% )
#imprimir shape

# %%
#Descripción de la Información de la tabla y tipo de datos

# %% [markdown]
# ### Convertir un campo tipo object a float

# %%
#Eliminar los caracteres'hg/ha'de todas las celdas del campo rendimiento para poder transformar el campo a numérico

# %%
# convertir el campo 'hg/ha_yield' de tipo object a float.
#puede usar este codigo como ejemplo df_yield['hg/ha_yield'] = pd.to_numeric(df_yield['hg/ha_yield'], errors='coerce')

# %%
#Descripción de la Información de la tabla y tipo de datos

# %%
# Resumen de estadísticas

# %% [markdown]
# #**3.Datos Climáticos: Precipitación** 💧
# Los factores climáticos como la precipitación, forma parte de los multiples factores ambientales que influyen en el crecimiento y desarrollo de un cultivo. Para este ejercicio, se recopiló información sobre la precipitación anual del [Banco Mundial](https://datos.bancomundial.org/).

# %% [markdown]
# ##Leer datos

# %%
df_rain = #Leer datos tabulares usando pandas

# %% [markdown]
# ##Explorar datos

# %%
#Obtener shape de los datos (filas,columnas)

# %%
#Lista de los nombres de los campos de una tabla

# %%
#Mostrar las primeras n filas

# %%
#Mostrar las ultimas n filas

# %%
#Descripción de la Información de la tabla y tipo de datos

# %%
# Resumen de estadísticas

# %% [markdown]
# ##Selección preliminar de características

# %% [markdown]
# ###Identificar campos con valores constantes, campos repetidos o redundantes

# %%
#Conteo de valores únicos por columna usando pandas

# %% [markdown]
# ##Limpieza de datos

# %% [markdown]
# ###Cambiar nombres de campos (Renombrar columnas)
# Al observar los nombres de los campos, podemos cambiar ' Area' por 'Area' para mantener la consistencia con la tabla base de redimiento y evitar problemas a la hora de trabajar o buscar el nombre de este campo.

# %%
# Renombrar campo

# %% [markdown]
# ### Convertir un campo de tipo object a float

# %%
# convertir el campo average_rain_fall_mm_per_year de tipo object a float

# %% [markdown]
# ###Identificar nulos (NaN)

# %%
# Calcular porcentaje de nulos por columna

# %%
# Calcular porcentaje de filas con al menos un NaN

# %%
#Mostrar las filas con valores nulos

# %% [markdown]
# ###Eliminar filas con valores nulos

# %%
#imprimir shape (filas, columnas) de la tabla antes de la eliminación para comparar

# %%
#Eliminar filas con valores nulos (usar cuando la cantidad relativa de filas con nulos es baja, menor del 20% )
#imprimir shape

# %%
#Descripción de la Información de la tabla y tipo de datos

# %% [markdown]
# El dataframe de precipitaciones comienza en 1985 y finaliza en 2017. Revisa el dataframe de producción , en qué año comienza y termina?

# %% [markdown]
# A continuación combine la tabla de producción con la tabla de precipitación usando el método merge de pandas y las columnas de year y area como campos clave.

# %% [markdown]
# ##Relacionar tablas por 2 campos clave

# %%
# relacionar el dataframe de rendimiento con el dataframe de precipitación por las columnas 'Year'y 'Area'
# con el objetivo de obtener los registros con informacion de la precipitación por año

# %% [markdown]
# Ahora, observamos la forma final del *dataframe* y la información de los valores:

# %%
# imprimir shape (filas, columnas) de la tabla

# %%
# mostrar los primeros n registros

# %%
# Revisar si hay nulos

# %%
#Eliminar nulos

# %%
# Resumen de estadísticas

# %% [markdown]
# Podemos ver que ahora los años comienzan desde 1985, mientras que en el primer *dataframe* de rendimiento el año inicial era 1961; esto se debe a que los datos de precipitación comienzan en 1985.

# %% [markdown]
# # **4.Datos de Pesticidas:** ☠
#
# Los pesticidas utilizados para cada producto y país también fueron recopilados de la base de datos de la FAO.

# %% [markdown]
# ##Leer datos

# %%
df_pes = #Leer datos tabulares usando pandas

# %% [markdown]
# ##Explorar datos

# %%
#Obtener shape de los datos (filas,columnas)

# %%
#Lista de los nombres de los campos de una tabla

# %%
# mostrar los primeros n registros

# %%
#mostrar los ultimos n resgistros

# %%
#Descripción de la Información de la tabla y tipo de datos

# %%
# Resumen de estadísticas

# %% [markdown]
# ##Selección preliminar de características

# %% [markdown]
# ###Identificar campos constantes, repetidos o redundantes

# %%
#Conteo de valores únicos por columna usando pandas

# %%
# Eliminar columnas no deseadas (conservando el orden de las columnas restantes).

# %% [markdown]
# ##Limpieza de datos

# %% [markdown]
# ###Cambiar nombres de campos (Renombrar columnas)

# %%
#cambiar el nombre del campo "Value" por "pesticides_tonnes"

# %%
#Descripción de la Información de la tabla y tipo de datos

# %% [markdown]
# ### Convertir un campo de tipo object a float

# %%
#Eliminar los caracteres "tonnes" de cada celda del campo 'pesticides_tonnes' para poder transformar el campo a un campo numérico

# %%
# convertir el campo 'pesticides_tonnes' de tipo object a float.

# %% [markdown]
# ###Identificar nulos (NaN)

# %%
# contar valores nulos (no hay valores nulos en este dataframe)

# %% [markdown]
# ###Eliminar filas con valores nulos

# %%
#Eliminar filas con valores nulos (usar cuando la cantidad relativa de filas con nulos es baja, menor del 20% )#

# %% [markdown]
# ###Relacionar tablas por 2 campos clave

# %%
# relacionar el *dataframe* de rendimiento con el *dataframe* de pesticidas usando los campos de 'Year','Area'

# %%
# mostrar los primeros n registros

# %%
#Descripción de la Información de la tabla y tipo de datos

# %%
# Resumen de estadísticas

# %% [markdown]
# # **5.Datos Temperatura Promedio:** 🔥
#
# La temperatura promedio de cada país fue recopilada de los datos del Banco Mundial.

# %% [markdown]
# ## Leer datos

# %%
avg_temp= # Leer archivo JSON directamente con pandas

# %% [markdown]
# ##Explorar datos

# %%
#imprimir shape

# %%
# mostar los primeros n registros

# %%
# mostrar los ultimos n registros

# %%
#Descripción de la Información de la tabla y tipo de datos

# %%
#Resumen de stadísticas

# %% [markdown]
# Entonces, la temperatura promedio comienza en 1743 y termina en 2013, con algunas filas vacías que debemos eliminar.

# %% [markdown]
# ## Selección prelimnar de características

# %% [markdown]
# ###Identificar campos con valores constantes, campos repetidos o redundantes

# %%
#Conteo de valores únicos por columna usando pandas

# %% [markdown]
# ##Limpieza de datos

# %% [markdown]
# ###Cambiar nombres de campos (Renombrar columnas)

# %%
# Cambair el nombre del campo "year"por "Year" y "country" por 'Area' para que sean consistentes con las demas tablas

# %% [markdown]
# ###Identificar nulos

# %%
# porcentaje de nulos por columna

# %%
# Calcular porcentaje de filas con al menos un NaN

# %%
#Mostrar las filas con valores nulos

# %% [markdown]
# ###Eliminar filas con valores nulos

# %%
#Por defecto elimina las filas que poseen algún valor nulo

# %% [markdown]
# ##Relacionar tablas por 2 campos clave

# %%
# relacionar el *dataframe* de rendimiento con el *dataframe* de temperatura  por los campos 'Area','Year'

# %%
#Obtener shape de los datos (filas,columnas)

# %%
# Resumen de estadísticas de la tabla final

# %%
# Revisar si hay nulos

# %% [markdown]
# ¡Genial, no hay valores vacíos!

# %%
#Descripción de la Información de la tabla final y tipo de datos

# %% [markdown]
# ##Registros duplicados

# %%
# explorar registros duplicados

# %%
#Eliminar registros duplicados

# %%
##Ejemplo de tabla resultado, no debe contener nulos ni duplicados y los últimos 4 campos deben ser numéricos
# Out:
#            Area   Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0       Albania  Maize  1990        36613                         1485.0
# 1       Albania  Maize  1991        29068                         1485.0
# 2       Albania  Maize  1992        24876                         1485.0
# 3       Albania  Maize  1993        24185                         1485.0
# 4       Albania  Maize  1994        25848                         1485.0
# ...         ...    ...   ...          ...                            ...
# 28242  Zimbabwe  Wheat  2009        30000                          657.0
# 28243  Zimbabwe  Wheat  2010        27681                          657.0
# 28244  Zimbabwe  Wheat  2011        26274                          657.0
# 28245  Zimbabwe  Wheat  2012        24420                          657.0
# 28246  Zimbabwe  Wheat  2013        22888                          657.0
#
#        pesticides_tonnes  avg_temp
# 0                 121.00     16.37
# ...

# %% [markdown]
# # **6.Datos consolidados** 📊

# %% [markdown]
# **yield_df** es el *dataframe* final obtenido.

# %%
#Agrupar los datos por tipo de cultivo y contar la cantidad de registros asociados a cada grupo (cultivo)
yield_df.groupby('Item').count()

# %%
# cuántos valores únicos(areas,zonas o paises) hay?

# %%
#Mostrar nombre de todos los paises
#¿Está Colombia…?

# %%
# Pasar el campo Area a minuscula

# %%
# Teniendo en cuenta los anterior¿cuántos resgistros corresponden a Colombia?

# %%
# ordenar los paises de mayor a menor rendiemiento y mostrar los 10 primeros
#yield_df.groupby(['Area'],sort=True)['hg/ha_yield'].sum().nlargest(10)

# %%
#Cuál pais tiene mayor producción por tipo de cultivo? mostrar los 10 primeros
